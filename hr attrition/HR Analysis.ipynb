# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # load data

# %%
df = pd.read_csv('D:\DATA ANALYSIS\HR Emp Attrition.csv')
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# # EDA

# %%
df
# Out:
#       EmployeeNumber  Gender EducationField  Age MaritalStatus  \
# 0                  1  Female  Life Sciences   41        Single
# 1                  2    Male  Life Sciences   49       Married
# 2                  4    Male          Other   37        Single
# 3                  5  Female  Life Sciences   33       Married
# 4                  7    Male        Medical   27       Married
# ...              ...     ...            ...  ...           ...
# 1465            2061    Male        Medical   36       Married
# 1466            2062    Male        Medical   39       Married
# 1467            2064    Male  Life Sciences   27       Married
# 1468            2065    Male        Medical   49       Married
# 1469            2068    Male        Medical   34       Married
#
#                   Department                    JobRole Attrition  \
# 0                      Sales            Sales Executive       Yes
# 1     Research & Development         Research Scientist        No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### REMOVE DUPLICATE

# %%
df.isnull().sum()
# NO DUPLICATES
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# LEFT = Over18 and StandardHours and EmployeeCount coulmns
df = df[['EmployeeNumber', 'Gender', 'EducationField', 'Age','MaritalStatus', 'Department', 'JobRole', 'Attrition', 'BusinessTravel',
       'DailyRate', 'DistanceFromHome', 'Education',
       'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
       'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]
df.columns
# Out:
# Index(['EmployeeNumber', 'Gender', 'EducationField', 'Age', 'MaritalStatus',
#        'Department', 'JobRole', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'DistanceFromHome', 'Education', 'EnvironmentSatisfaction',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# Prepare the correlation matrix
correlation_matrix = (df.select_dtypes(include=['number'])).corr()
# Create a Heatmap
plt.figure(figsize=(16, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Map for Numeric Variables')
plt.show()

# %%
fig, axes = plt.subplots(len(df.columns)//2 +1, 2, figsize=(10, 60))

fig.subplots_adjust(hspace=2.5)
axes = axes.flatten()

# Create a loop to generate visualizations for all columns
for i, column in enumerate(df.columns):
    plt.sca(axes[i])
    if df[column].dtype == 'int64' or df[column].dtype == 'float64':
        sns.histplot(df[column], bins=10, kde=True, ax=axes[i])
        plt.title(f'{column} Distribution')
    else:
        sns.countplot(x=column, data=df, ax=axes[i])
        plt.title(f'Count of observations in {column}')
    plt.xlabel(column)
    plt.xticks(rotation=45)

# Remove any empty subplot if the number of columns is odd
if len(df.columns) % 2 != 0:
    fig.delaxes(axes[-1])
    
plt.show()

# %% [markdown]
# # seprating the quantititve and qualititive values

# %%
cat_cols=df.select_dtypes(include=['object']).columns
num_cols = df.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Gender', 'EducationField', 'MaritalStatus', 'Department', 'JobRole',
#        'Attrition', 'BusinessTravel', 'OverTime'],
#       dtype='object')
# Numerical Variables:
# ['EmployeeNumber', 'Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# # visual the numeric values with boxplot and bar

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(df[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    df[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col])
    plt.show()
# Out:
# EmployeeNumber
# Skew : 0.02
# Age
# Skew : 0.41
# DailyRate
# Skew : -0.0
# DistanceFromHome
# Skew : 0.96
# Education
# Skew : -0.29
# EnvironmentSatisfaction
# Skew : -0.32
# HourlyRate
# Skew : -0.03
# JobInvolvement
# Skew : -0.5
# JobLevel
# Skew : 1.03
# JobSatisfaction
# Skew : -0.33
# MonthlyIncome
# Skew : 1.37
# MonthlyRate
# Skew : 0.02
# NumCompaniesWorked
# Skew : 1.03
# PercentSalaryHike
# Skew : 0.82
# PerformanceRating
# Skew : 1.92
# RelationshipSatisfaction
# Skew : -0.3
# StockOptionLevel
# Skew : 0.97
# TotalWorkingYears
# Skew : 1.12
# TrainingTimesLastYear
# Skew : 0.55
# WorkLifeBalance
# Skew : -0.55
# YearsAtCompany
# Skew : 1.76
# YearsInCurrentRole
# Skew : 0.92
# YearsSinceLastPromotion
# Skew : 1.98
# YearsWithCurrManager
# Skew : 0.83

# %% [markdown]
# ##### outliers exists in (monthlyincome, numcompaniswork, performancerating, stockoptionlevel, totalworkingyears, TrainingTimesLastYear, yearatcompany, yearsincurrentroleyearsscincelastpromotion, yearswithcurruntmanger)

# %%
df.to_csv('HR_Attrition.csv')
